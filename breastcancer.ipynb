# %% [markdown]
# **READING DATASET**

# %%
import numpy as np
import pandas as pd

# %%
data=pd.read_csv("/content/data.csv")

# %%
data
# Out:
#            id diagnosis  ...  fractal_dimension_worst  Unnamed: 32
# 0      842302         M  ...                  0.11890          NaN
# 1      842517         M  ...                  0.08902          NaN
# 2    84300903         M  ...                  0.08758          NaN
# 3    84348301         M  ...                  0.17300          NaN
# 4    84358402         M  ...                  0.07678          NaN
# ..        ...       ...  ...                      ...          ...
# 564    926424         M  ...                  0.07115          NaN
# 565    926682         M  ...                  0.06637          NaN
# 566    926954         M  ...                  0.07820          NaN
# 567    927241         M  ...                  0.12400          NaN
# 568     92751         B  ...                  0.07039          NaN
#
# [569 rows x 33 columns]

# %%
data.describe()
# Out:
#                  id  radius_mean  ...  fractal_dimension_worst  Unnamed: 32
# count  5.690000e+02   569.000000  ...               569.000000          0.0
# mean   3.037183e+07    14.127292  ...                 0.083946          NaN
# std    1.250206e+08     3.524049  ...                 0.018061          NaN
# min    8.670000e+03     6.981000  ...                 0.055040          NaN
# 25%    8.692180e+05    11.700000  ...                 0.071460          NaN
# 50%    9.060240e+05    13.370000  ...                 0.080040          NaN
# 75%    8.813129e+06    15.780000  ...                 0.092080          NaN
# max    9.113205e+08    28.110000  ...                 0.207500          NaN
#
# [8 rows x 32 columns]

# %%
data.value_counts
# Out:
# <bound method DataFrame.value_counts of            id diagnosis  ...  fractal_dimension_worst  Unnamed: 32
# 0      842302         M  ...                  0.11890          NaN
# 1      842517         M  ...                  0.08902          NaN
# 2    84300903         M  ...                  0.08758          NaN
# 3    84348301         M  ...                  0.17300          NaN
# 4    84358402         M  ...                  0.07678          NaN
# ..        ...       ...  ...                      ...          ...
# 564    926424         M  ...                  0.07115          NaN
# 565    926682         M  ...                  0.06637          NaN
# 566    926954         M  ...                  0.07820          NaN
# 567    927241         M  ...                  0.12400          NaN
# 568     92751         B  ...                  0.07039          NaN
#
# [569 rows x 33 columns]>

# %%
data.shape
# Out:
# (569, 33)

# %%
data.isnull().sum()
# Out:
# id                           0
# diagnosis                    0
# radius_mean                  0
# texture_mean                 0
# perimeter_mean               0
# area_mean                    0
# smoothness_mean              0
# compactness_mean             0
# concavity_mean               0
# concave points_mean          0
# symmetry_mean                0
# fractal_dimension_mean       0
# radius_se                    0
# texture_se                   0
# perimeter_se                 0
# area_se                      0
# smoothness_se                0
# compactness_se               0
# concavity_se                 0
# concave points_se            0
# symmetry_se                  0
# fractal_dimension_se         0
# radius_worst                 0
# texture_worst                0
# perimeter_worst              0
# area_worst                   0
# smoothness_worst             0
# compactness_worst            0
# concavity_worst              0
# concave points_worst         0
# symmetry_worst               0
# fractal_dimension_worst      0
# Unnamed: 32                569
# dtype: int64

# %% [markdown]
# **PREPROCESSING**

# %%
data = data.drop('id',axis=1)
data = data.drop('Unnamed: 32',axis=1)
data['diagnosis'] = data['diagnosis'].map({'M':1,'B':0})
data.describe()
# Out:
#         diagnosis  radius_mean  ...  symmetry_worst  fractal_dimension_worst
# count  569.000000   569.000000  ...      569.000000               569.000000
# mean     0.372583    14.127292  ...        0.290076                 0.083946
# std      0.483918     3.524049  ...        0.061867                 0.018061
# min      0.000000     6.981000  ...        0.156500                 0.055040
# 25%      0.000000    11.700000  ...        0.250400                 0.071460
# 50%      0.000000    13.370000  ...        0.282200                 0.080040
# 75%      1.000000    15.780000  ...        0.317900                 0.092080
# max      1.000000    28.110000  ...        0.663800                 0.207500
#
# [8 rows x 31 columns]

# %%
X = data.iloc[:, :-1].values
y = data.iloc[:, -1].values

# %%
X
# Out:
# array([[ 1.    , 17.99  , 10.38  , ...,  0.7119,  0.2654,  0.4601],
#        [ 1.    , 20.57  , 17.77  , ...,  0.2416,  0.186 ,  0.275 ],
#        [ 1.    , 19.69  , 21.25  , ...,  0.4504,  0.243 ,  0.3613],
#        ...,
#        [ 1.    , 16.6   , 28.08  , ...,  0.3403,  0.1418,  0.2218],
#        [ 1.    , 20.6   , 29.33  , ...,  0.9387,  0.265 ,  0.4087],
#        [ 0.    ,  7.76  , 24.54  , ...,  0.    ,  0.    ,  0.2871]])

# %%
y
# Out:
# array([0.1189 , 0.08902, 0.08758, 0.173  , 0.07678, 0.1244 , 0.08368,
#        0.1151 , 0.1072 , 0.2075 , 0.08452, 0.1048 , 0.1023 , 0.06287,
#        0.1431 , 0.1341 , 0.08216, 0.1142 , 0.07615, 0.07259, 0.08183,
#        0.07773, 0.09946, 0.07526, 0.09564, 0.1059 , 0.1275 , 0.07421,
#        0.09876, 0.07919, 0.09782, 0.1402 , 0.08482, 0.1123 , 0.1233 ,
#        0.08633, 0.1014 , 0.06169, 0.05504, 0.1071 , 0.07146, 0.09606,
#        0.1038 , 0.1027 , 0.09618, 0.09185, 0.07409, 0.1179 , 0.08301,
#        0.06917, 0.06563, 0.08025, 0.07408, 0.07987, 0.07873, 0.07036,
#        0.08294, 0.1094 , 0.06289, 0.09026, 0.0802 , 0.07712, 0.1132 ,
#        0.0849 , 0.1031 , 0.08911, 0.09211, 0.06641, 0.1175 , 0.0641 ,
#        0.06589, 0.1084 , 0.1339 , 0.103  , 0.07609, 0.06387, 0.07191,
#        0.1108 , 0.09964, 0.07918, 0.08851, 0.1016 , 0.1051 , 0.09203,
#        0.124  , 0.07039])

# %%
from sklearn import preprocessing

# %%
datas = pd.DataFrame(preprocessing.scale(data.iloc[:,1:32]))
datas.columns = list(data.iloc[:,1:32].columns)
datas['diagnosis'] = data['diagnosis']
datas.head()
# Out:
#    radius_mean  texture_mean  ...  fractal_dimension_worst  diagnosis
# 0     1.097064     -2.073335  ...                 1.937015          1
# 1     1.829821     -0.353632  ...                 0.281190          1
# 2     1.579888      0.456187  ...                 0.201391          1
# 3    -0.768909      0.253732  ...                 4.935010          1
# 4     1.750297     -1.151816  ...                -0.397100          1
#
# [5 rows x 31 columns]

# %%
from sklearn.preprocessing import MinMaxScaler
sc = MinMaxScaler()
X = sc.fit_transform(X)

# %%
X
# Out:
# array([[1.        , 0.52103744, 0.0226581 , ..., 0.56861022, 0.91202749,
#         0.59846245],
#        [1.        , 0.64314449, 0.27257355, ..., 0.19297125, 0.63917526,
#         0.23358959],
#        [1.        , 0.60149557, 0.3902604 , ..., 0.35974441, 0.83505155,
#         0.40370589],
#        ...,
#        [1.        , 0.45525108, 0.62123774, ..., 0.27180511, 0.48728522,
#         0.12872068],
#        [1.        , 0.64456434, 0.66351031, ..., 0.74976038, 0.91065292,
#         0.49714173],
#        [0.        , 0.03686876, 0.50152181, ..., 0.        , 0.        ,
#         0.25744136]])

# %% [markdown]
# **VISUALIZING**

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
features_mean = ['radius_mean','texture_mean','perimeter_mean','area_mean','smoothness_mean', 'compactness_mean', 'concavity_mean','concave points_mean',
                 'symmetry_mean', 'fractal_dimension_mean']
plt.figure(figsize=(15,15))
heat = sns.heatmap(datas[features_mean].corr(), vmax=1, square=True, annot=True)

# %% [markdown]
# **The correlation coefficient ranges from -1 to 1. If the value is close to 1, it means that there is a strong positive correlation between the two variables. When it is close to -1, the variables have a strong negative correlation**

# %%
data_drop = datas.drop('diagnosis',axis=1)
data_drop = data_drop[features_mean]
for index,columns in enumerate(data_drop):
    plt.figure(index)
    plt.figure(figsize=(15,15))
    sns.stripplot(x='diagnosis', y= columns, data= datas, jitter=True, palette = 'Set1');

# %%
from sklearn.decomposition import PCA 
X = data_drop.values
pca = PCA(n_components=2) 
pca = pca.fit_transform(X)
plt.figure(figsize = (9,5))
plt.scatter(pca[:,0],pca[:,1], c = datas['diagnosis'], cmap = "RdBu_r", edgecolor = "Red", alpha=0.35)
plt.colorbar()
plt.title('PCA Scatter Plot')
# Out:
# Text(0.5, 1.0, 'PCA Scatter Plot')

# %% [markdown]
# **MODELLING**

# %%
cancerData = datasets.load_breast_cancer()
X = pd.DataFrame(data = cancerData.data, columns=cancerData.feature_names )

# %%
y = cancerData.target

# %%
from sklearn.preprocessing import LabelEncoder
labelencoder_X_1 = LabelEncoder()
y = labelencoder_X_1.fit_transform(y)

# %%
scaler = StandardScaler()

# %%
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
X_train,X_test,y_train,y_test= train_test_split(X,y,test_size=0.1)

# %%
X_train.shape
# Out:
# (512, 30)

# %%
y_test.shape
# Out:
# (57,)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
X_train = X_train.reshape(512,30,1)
X_test = X_test.reshape(57,30,1)

# %%
import keras
from keras.models import Sequential
from keras.layers import Dense, Dropout

# %%
model = Sequential()

# %%
model.add(Conv1D(filters=16,kernel_size=2,activation='relu',input_shape=(30,1)))
model.add(BatchNormalization())
model.add(Dropout(0.2))

model.add(Conv1D(32,2,activation='relu'))
model.add(BatchNormalization())
model.add(Dropout(0.2))

model.add(Flatten())
model.add(Dense(32,activation='relu'))
model.add(Dropout(0.2))

model.add(Dense(1,activation='sigmoid'))

# %%
model.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_7 (Conv1D)            (None, 29, 16)            48
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 29, 16)            64
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 29, 16)            0
# _________________________________________________________________
# conv1d_8 (Conv1D)            (None, 28, 32)            1056
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 28, 32)            128
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 28, 32)            0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 896)               0
# _________________________________________________________________
# dense_7 (Dense)              (None, 32)                28704
# _________________________________________________________________
# dropout_11 (Dropout)         (None, 32)                0
# _________________________________________________________________
# dense_8 (Dense)              (None, 1)                 33
# =================================================================
# Total params: 30,033
# Trainable params: 29,937
# Non-trainable params: 96
# _________________________________________________________________

# %%
model.compile(optimizer=Adam(learning_rate=0.0001),loss='binary_crossentropy',metrics=['accuracy'])

# %%
history = model.fit(X_train,y_train,epochs=35,verbose=1,validation_data=(X_test,y_test))
# Out:
# Epoch 1/35
# 16/16 [==============================] - 1s 18ms/step - loss: 0.7717 - accuracy: 0.5664 - val_loss: 0.6359 - val_accuracy: 0.8070
# Epoch 2/35
# 16/16 [==============================] - 0s 6ms/step - loss: 0.5005 - accuracy: 0.7617 - val_loss: 0.5957 - val_accuracy: 0.8947
# Epoch 3/35
# 16/16 [==============================] - 0s 6ms/step - loss: 0.3880 - accuracy: 0.8359 - val_loss: 0.5517 - val_accuracy: 0.8772
# Epoch 4/35
# 16/16 [==============================] - 0s 6ms/step - loss: 0.3382 - accuracy: 0.8574 - val_loss: 0.5142 - val_accuracy: 0.8421
# Epoch 5/35
# 16/16 [==============================] - 0s 6ms/step - loss: 0.2742 - accuracy: 0.9062 - val_loss: 0.4751 - val_accuracy: 0.8246
# Epoch 6/35
# 16/16 [==============================] - 0s 6ms/step - loss: 0.2536 - accuracy: 0.9082 - val_loss: 0.4399 - val_accuracy: 0.8246
# Epoch 7/35
# 16/16 [==============================] - 0s 6ms/step - loss: 0.2094 - accuracy: 0.9355 - val_loss: 0.4067 - val_accuracy: 0.8246
# Epoch 8/35
# 16/16 [==============================] - 0s 6ms/step - loss: 0.2016 - accuracy: 0.9199 - val_loss: 0.3772 - val_accuracy: 0.8246
# Epoch 9/35
# 16/16 [==============================] - 0s 6ms/step - loss: 0.1844 - accuracy: 0.9258 - val_loss: 0.3491 - val_accuracy: 0.8246
# Epoch 10/35
# 16/16 [==============================] - 0s 6ms/step - loss: 0.1693 - accuracy: 0.9512 - val_loss: 0.3224 - val_accuracy: 0.8246
# Epoch 11/35
# 16/16 [==============================] - 0s 5ms/step - loss: 0.1719 - accuracy: 0.9531 - val_loss: 0.2995 - val_accuracy: 0.8246
# Epoch 12/35
# 16/16 [==============================] - 0s 7ms/step - loss: 0.1674 - accuracy: 0.9395 - val_loss: 0.2815 - val_accuracy: 0.8596
# Epoch 13/35
# 16/16 [==============================] - 0s 6ms/step - loss: 0.1439 - accuracy: 0.9512 - val_loss: 0.2655 - val_accuracy: 0.8772
# Epoch 14/35
# 16/16 [==============================] - 0s 5ms/step - loss: 0.1450 - accuracy: 0.9629 - val_loss: 0.2482 - val_accuracy: 0.8947
# Epoch 15/35
# 16/16 [==============================] - 0s 6ms/step - loss: 0.1261 - accuracy: 0.9512 - val_loss: 0.2296 - val_accuracy: 0.9123
# Epoch 16/35
# 16/16 [==============================] - 0s 6ms/step - loss: 0.1391 - accuracy: 0.9512 - val_loss: 0.2212 - val_accuracy: 0.9123
# Epoch 17/35
# 16/16 [==============================] - 0s 6ms/step - loss: 0.1118 - accuracy: 0.9590 - val_loss: 0.2080 - val_accuracy: 0.9123
# Epoch 18/35
# 16/16 [==============================] - 0s 6ms/step - loss: 0.1033 - accuracy: 0.9707 - val_loss: 0.1986 - val_accuracy: 0.9298
# Epoch 19/35
# 16/16 [==============================] - 0s 6ms/step - loss: 0.1101 - accuracy: 0.9668 - val_loss: 0.1903 - val_accuracy: 0.9298
# Epoch 20/35
# 16/16 [==============================] - 0s 6ms/step - loss: 0.1009 - accuracy: 0.9727 - val_loss: 0.1828 - val_accuracy: 0.9298
# Epoch 21/35
# 16/16 [==============================] - 0s 6ms/step - loss: 0.1255 - accuracy: 0.9492 - val_loss: 0.1802 - val_accuracy: 0.9298
# Epoch 22/35
# 16/16 [==============================] - 0s 6ms/step - loss: 0.1131 - accuracy: 0.9668 - val_loss: 0.1759 - val_accuracy: 0.9298
# Epoch 23/35
# 16/16 [==============================] - 0s 6ms/step - loss: 0.1000 - accuracy: 0.9688 - val_loss: 0.1680 - val_accuracy: 0.9298
# Epoch 24/35
# 16/16 [==============================] - 0s 6ms/step - loss: 0.1055 - accuracy: 0.9707 - val_loss: 0.1649 - val_accuracy: 0.9298
# Epoch 25/35
# 16/16 [==============================] - 0s 6ms/step - loss: 0.1007 - accuracy: 0.9648 - val_loss: 0.1590 - val_accuracy: 0.9298
# Epoch 26/35
# 16/16 [==============================] - 0s 7ms/step - loss: 0.0849 - accuracy: 0.9746 - val_loss: 0.1577 - val_accuracy: 0.9298
# Epoch 27/35
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0790 - accuracy: 0.9707 - val_loss: 0.1576 - val_accuracy: 0.9298
# Epoch 28/35
# 16/16 [==============================] - 0s 5ms/step - loss: 0.0879 - accuracy: 0.9707 - val_loss: 0.1562 - val_accuracy: 0.9298
# Epoch 29/35
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0915 - accuracy: 0.9707 - val_loss: 0.1518 - val_accuracy: 0.9298
# Epoch 30/35
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0854 - accuracy: 0.9785 - val_loss: 0.1504 - val_accuracy: 0.9298
# Epoch 31/35
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0815 - accuracy: 0.9707 - val_loss: 0.1514 - val_accuracy: 0.9298
# Epoch 32/35
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0853 - accuracy: 0.9766 - val_loss: 0.1581 - val_accuracy: 0.9298
# Epoch 33/35
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0841 - accuracy: 0.9766 - val_loss: 0.1591 - val_accuracy: 0.9123
# Epoch 34/35
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0856 - accuracy: 0.9707 - val_loss: 0.1610 - val_accuracy: 0.9123
# Epoch 35/35
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0862 - accuracy: 0.9746 - val_loss: 0.1568 - val_accuracy: 0.9474

# %%
def plotLearningCurve(history,epochs):
  epochRange = range(1,epochs+1)
  plt.plot(epochRange,history.history['accuracy'])
  plt.plot(epochRange,history.history['val_accuracy'])
  plt.title('Model Accuracy')
  plt.xlabel('Epoch')
  plt.ylabel('Accuracy')
  plt.legend(['Train','Validation'],loc='upper left')
  plt.show()

  plt.plot(epochRange,history.history['loss'])
  plt.plot(epochRange,history.history['val_loss'])
  plt.title('Model Loss')
  plt.xlabel('Epoch')
  plt.ylabel('Loss')
  plt.legend(['Train','Validation'],loc='upper left')
  plt.show()

# %%
plotLearningCurve(history,35)
